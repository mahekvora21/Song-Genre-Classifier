# %%
import pandas as pd
import numpy as np

# %%
english_lyrics = pd.read_csv('../Desktop/song_lyrics_classifier/english_lyrics.csv')

# %%
english_lyrics.shape
# Out:
# (218210, 7)

# %%
original_lyrics = pd.read_csv('../Desktop/song_lyrics_classifier/original_lyrics.csv')

# %%
original_lyrics.shape
# Out:
# (227449, 7)

# %%
english_lyrics.head()
# Out:
#    Unnamed: 0  index             song  year           artist genre  \
# 0           0      0        ego-remix  2009  beyonce-knowles   Pop
# 1           1      1     then-tell-me  2009  beyonce-knowles   Pop
# 2           2      2          honesty  2009  beyonce-knowles   Pop
# 3           3      3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4           4      4    black-culture  2009  beyonce-knowles   Pop
#
#                                               lyrics
# 0  Oh baby how you doing You know I'm gonna cut r...
# 1  playin everything so easy it's like you seem s...
# 2  If you search For tenderness It isn't hard to ...
# 3  Oh oh oh I oh oh oh I If I wrote a book about ...
# 4  Party the people the people the party it's pop...

# %%
original_lyrics.head()
# Out:
#    Unnamed: 0  index             song  year           artist genre  \
# 0           0      0        ego-remix  2009  beyonce-knowles   Pop
# 1           1      1     then-tell-me  2009  beyonce-knowles   Pop
# 2           2      2          honesty  2009  beyonce-knowles   Pop
# 3           3      3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4           4      4    black-culture  2009  beyonce-knowles   Pop
#
#                                               lyrics
# 0  Oh baby how you doing You know I'm gonna cut r...
# 1  playin everything so easy it's like you seem s...
# 2  If you search For tenderness It isn't hard to ...
# 3  Oh oh oh I oh oh oh I If I wrote a book about ...
# 4  Party the people the people the party it's pop...

# %%
original_lyrics.tail()
# Out:
#         Unnamed: 0   index                         song  year      artist  \
# 227444      362232  362232    who-am-i-drinking-tonight  2012  edens-edge
# 227445      362233  362233                         liar  2012  edens-edge
# 227446      362234  362234                  last-supper  2012  edens-edge
# 227447      362235  362235  christ-alone-live-in-studio  2012  edens-edge
# 227448      362236  362236                         amen  2012  edens-edge
#
#           genre                                             lyrics
# 227444  Country  I gotta say Boy after only just a couple of da...
# 227445  Country  I helped you find her diamond ring You made me...
# 227446  Country  Look at the couple in the corner booth Looks a...
# 227447  Country  When I fly off this mortal earth And I'm measu...
# 227448  Country  I heard from a friend of a friend of a friend ...

# %%
english_lyrics.tail()
# Out:
#         Unnamed: 0   index                         song  year      artist  \
# 218205      362232  362232    who-am-i-drinking-tonight  2012  edens-edge
# 218206      362233  362233                         liar  2012  edens-edge
# 218207      362234  362234                  last-supper  2012  edens-edge
# 218208      362235  362235  christ-alone-live-in-studio  2012  edens-edge
# 218209      362236  362236                         amen  2012  edens-edge
#
#           genre                                             lyrics
# 218205  Country  I gotta say Boy after only just a couple of da...
# 218206  Country  I helped you find her diamond ring You made me...
# 218207  Country  Look at the couple in the corner booth Looks a...
# 218208  Country  When I fly off this mortal earth And I'm measu...
# 218209  Country  I heard from a friend of a friend of a friend ...

# %%
original_lyrics.replace('NA', np.nan, inplace=True)
original_lyrics.replace('missing', np.nan, inplace=True)

# %%
original_lyrics.dropna()
# Out:
#         Unnamed: 0   index                         song  year  \
# 0                0       0                    ego-remix  2009
# 1                1       1                 then-tell-me  2009
# 2                2       2                      honesty  2009
# 3                3       3              you-are-my-rock  2009
# 4                4       4                black-culture  2009
# ...            ...     ...                          ...   ...
# 227444      362232  362232    who-am-i-drinking-tonight  2012
# 227445      362233  362233                         liar  2012
# 227446      362234  362234                  last-supper  2012
# 227447      362235  362235  christ-alone-live-in-studio  2012
# 227448      362236  362236                         amen  2012
#
#                  artist    genre  \
# 0       beyonce-knowles      Pop
# 1       beyonce-knowles      Pop
# 2       beyonce-knowles      Pop
# 3       beyonce-knowles      Pop
# 4       beyonce-knowles      Pop
# ...

# %%
original_lyrics.shape
# Out:
# (227449, 7)

# %%
english_lyrics.dropna(axis='index', how='any', subset=['song', 'genre', 'lyrics'])
# Out:
#         Unnamed: 0   index                         song  year  \
# 0                0       0                    ego-remix  2009
# 1                1       1                 then-tell-me  2009
# 2                2       2                      honesty  2009
# 3                3       3              you-are-my-rock  2009
# 4                4       4                black-culture  2009
# ...            ...     ...                          ...   ...
# 218205      362232  362232    who-am-i-drinking-tonight  2012
# 218206      362233  362233                         liar  2012
# 218207      362234  362234                  last-supper  2012
# 218208      362235  362235  christ-alone-live-in-studio  2012
# 218209      362236  362236                         amen  2012
#
#                  artist    genre  \
# 0       beyonce-knowles      Pop
# 1       beyonce-knowles      Pop
# 2       beyonce-knowles      Pop
# 3       beyonce-knowles      Pop
# 4       beyonce-knowles      Pop
# ...

# %%
original_lyrics.shape
# Out:
# (227449, 7)

# %%
english_lyrics.isnull().sum()
# Out:
# Unnamed: 0    0
# index         0
# song          1
# year          0
# artist        0
# genre         0
# lyrics        0
# dtype: int64

# %%
original_lyrics.isnull().sum()
# Out:
# Unnamed: 0     0
# index          0
# song          22
# year           0
# artist         0
# genre          0
# lyrics         0
# dtype: int64

# %%
english_lyrics.drop(['Unnamed: 0', 'song', 'artist'], axis=1, inplace=True)
english_lyrics
# Out:
#          index  year    genre  \
# 0            0  2009      Pop
# 1            1  2009      Pop
# 2            2  2009      Pop
# 3            3  2009      Pop
# 4            4  2009      Pop
# ...        ...   ...      ...
# 218205  362232  2012  Country
# 218206  362233  2012  Country
# 218207  362234  2012  Country
# 218208  362235  2012  Country
# 218209  362236  2012  Country
#
#                                                    lyrics
# 0       Oh baby how you doing You know I'm gonna cut r...
# 1       playin everything so easy it's like you seem s...
# 2       If you search For tenderness It isn't hard to ...
# 3       Oh oh oh I oh oh oh I If I wrote a book about ...
# 4       Party the people the people the party it's pop...
# ...                                                   ...
# 218205  I gotta say Boy after only just a couple of da...
# 218206  I helped you find her diamond ring You made me...
# 218207  Look at the couple in the corner booth Looks a...
# ...

# %%
original_lyrics.isnull().sum()
# Out:
# Unnamed: 0     0
# index          0
# song          22
# year           0
# artist         0
# genre          0
# lyrics         0
# dtype: int64

# %%
english_lyrics.isnull().sum()
# Out:
# index     0
# year      0
# genre     0
# lyrics    0
# dtype: int64

# %%
grouped_english_lyrics=english_lyrics.groupby('genre')

# %%
grouped_english_lyrics.count()
# Out:
#              index    year  lyrics
# genre
# Country      14158   14158   14158
# Electronic    6942    6942    6942
# Folk          1689    1689    1689
# Hip-Hop      22654   22654   22654
# Indie         2935    2935    2935
# Jazz          7310    7310    7310
# Metal        21210   21210   21210
# Other         3786    3786    3786
# Pop          34137   34137   34137
# R&B           3336    3336    3336
# Rock        100053  100053  100053

# %%
grouped_original_lyrics=english_lyrics.groupby('genre')

# %%
grouped_original_lyrics.count()
# Out:
#              index    year  lyrics
# genre
# Country      14158   14158   14158
# Electronic    6942    6942    6942
# Folk          1689    1689    1689
# Hip-Hop      22654   22654   22654
# Indie         2935    2935    2935
# Jazz          7310    7310    7310
# Metal        21210   21210   21210
# Other         3786    3786    3786
# Pop          34137   34137   34137
# R&B           3336    3336    3336
# Rock        100053  100053  100053

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/mahekvora/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
english_lyrics.head()
# Out:
#    index  year genre                                             lyrics
# 0      0  2009   Pop  Oh baby how you doing You know I'm gonna cut r...
# 1      1  2009   Pop  playin everything so easy it's like you seem s...
# 2      2  2009   Pop  If you search For tenderness It isn't hard to ...
# 3      3  2009   Pop  Oh oh oh I oh oh oh I If I wrote a book about ...
# 4      4  2009   Pop  Party the people the people the party it's pop...

# %%
english_lyrics['lyrics'] = english_lyrics.apply(lambda col: nltk.word_tokenize(col['lyrics']), axis=1)
english_lyrics
# Out:
#          index  year    genre  \
# 0            0  2009      Pop
# 1            1  2009      Pop
# 2            2  2009      Pop
# 3            3  2009      Pop
# 4            4  2009      Pop
# ...        ...   ...      ...
# 218205  362232  2012  Country
# 218206  362233  2012  Country
# 218207  362234  2012  Country
# 218208  362235  2012  Country
# 218209  362236  2012  Country
#
#                                                    lyrics
# 0       [Oh, baby, how, you, doing, You, know, I, 'm, ...
# 1       [playin, everything, so, easy, it, 's, like, y...
# 2       [If, you, search, For, tenderness, It, is, n't...
# 3       [Oh, oh, oh, I, oh, oh, oh, I, If, I, wrote, a...
# 4       [Party, the, people, the, people, the, party, ...
# ...                                                   ...
# 218205  [I, got, ta, say, Boy, after, only, just, a, c...
# 218206  [I, helped, you, find, her, diamond, ring, You...
# 218207  [Look, at, the, couple, in, the, corner, booth...
# ...

# %%
english_lyrics['lyrics'] = english_lyrics['lyrics'].apply(lambda x: [item.lower() for item in x])
english_lyrics
# Out:
#          index  year    genre  \
# 0            0  2009      Pop
# 1            1  2009      Pop
# 2            2  2009      Pop
# 3            3  2009      Pop
# 4            4  2009      Pop
# ...        ...   ...      ...
# 218205  362232  2012  Country
# 218206  362233  2012  Country
# 218207  362234  2012  Country
# 218208  362235  2012  Country
# 218209  362236  2012  Country
#
#                                                    lyrics
# 0       [oh, baby, how, you, doing, you, know, i, 'm, ...
# 1       [playin, everything, so, easy, it, 's, like, y...
# 2       [if, you, search, for, tenderness, it, is, n't...
# 3       [oh, oh, oh, i, oh, oh, oh, i, if, i, wrote, a...
# 4       [party, the, people, the, people, the, party, ...
# ...                                                   ...
# 218205  [i, got, ta, say, boy, after, only, just, a, c...
# 218206  [i, helped, you, find, her, diamond, ring, you...
# 218207  [look, at, the, couple, in, the, corner, booth...
# ...

# %%
import re
english_lyrics['lyrics']=english_lyrics['lyrics'].apply(lambda x: [re.sub(r'[^\w\s]',"",item) for item in x ])
english_lyrics
# Out:
#          index  year    genre  \
# 0            0  2009      Pop
# 1            1  2009      Pop
# 2            2  2009      Pop
# 3            3  2009      Pop
# 4            4  2009      Pop
# ...        ...   ...      ...
# 218205  362232  2012  Country
# 218206  362233  2012  Country
# 218207  362234  2012  Country
# 218208  362235  2012  Country
# 218209  362236  2012  Country
#
#                                                    lyrics
# 0       [oh, baby, how, you, doing, you, know, i, m, g...
# 1       [playin, everything, so, easy, it, s, like, yo...
# 2       [if, you, search, for, tenderness, it, is, nt,...
# 3       [oh, oh, oh, i, oh, oh, oh, i, if, i, wrote, a...
# 4       [party, the, people, the, people, the, party, ...
# ...                                                   ...
# 218205  [i, got, ta, say, boy, after, only, just, a, c...
# 218206  [i, helped, you, find, her, diamond, ring, you...
# 218207  [look, at, the, couple, in, the, corner, booth...
# ...

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mahekvora/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopWords=stopwords.words('english')

# %%
english_lyrics['lyrics']=english_lyrics['lyrics'].apply(lambda x: [item for item in x if item not in stopWords ])
english_lyrics
# Out:
#          index  year    genre  \
# 0            0  2009      Pop
# 1            1  2009      Pop
# 2            2  2009      Pop
# 3            3  2009      Pop
# 4            4  2009      Pop
# ...        ...   ...      ...
# 218205  362232  2012  Country
# 218206  362233  2012  Country
# 218207  362234  2012  Country
# 218208  362235  2012  Country
# 218209  362236  2012  Country
#
#                                                    lyrics
# 0       [oh, baby, know, gon, na, cut, right, chase, w...
# 1       [playin, everything, easy, like, seem, sure, s...
# 2       [search, tenderness, nt, hard, find, love, nee...
# 3       [oh, oh, oh, oh, oh, oh, wrote, book, stand, t...
# 4       [party, people, people, party, popping, sittin...
# ...                                                   ...
# 218205  [got, ta, say, boy, couple, dates, hands, outr...
# 218206  [helped, find, diamond, ring, made, try, every...
# 218207  [look, couple, corner, booth, looks, lot, like...
# ...

# %%
from nltk.stem.porter import PorterStemmer

# %%
port = PorterStemmer()

# %%
english_lyrics['lyrics'] = english_lyrics['lyrics'].apply(lambda x: [port.stem(item) for item in x])
english_lyrics
# Out:
#          index  year    genre  \
# 0            0  2009      Pop
# 1            1  2009      Pop
# 2            2  2009      Pop
# 3            3  2009      Pop
# 4            4  2009      Pop
# ...        ...   ...      ...
# 218205  362232  2012  Country
# 218206  362233  2012  Country
# 218207  362234  2012  Country
# 218208  362235  2012  Country
# 218209  362236  2012  Country
#
#                                                    lyrics
# 0       [oh, babi, know, gon, na, cut, right, chase, w...
# 1       [playin, everyth, easi, like, seem, sure, stil...
# 2       [search, tender, nt, hard, find, love, need, l...
# 3       [oh, oh, oh, oh, oh, oh, wrote, book, stand, t...
# 4       [parti, peopl, peopl, parti, pop, sit, around,...
# ...                                                   ...
# 218205  [got, ta, say, boy, coupl, date, hand, outrigh...
# 218206  [help, find, diamond, ring, made, tri, everyth...
# 218207  [look, coupl, corner, booth, look, lot, like, ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
english_lyrics_df=pd.DataFrame(english_lyrics)

# %%
print(english_lyrics_df)
# Out:
#          index  year    genre  \
# 0            0  2009      Pop
# 1            1  2009      Pop
# 2            2  2009      Pop
# 3            3  2009      Pop
# 4            4  2009      Pop
# ...        ...   ...      ...
# 218205  362232  2012  Country
# 218206  362233  2012  Country
# 218207  362234  2012  Country
# 218208  362235  2012  Country
# 218209  362236  2012  Country
#
#                                                    lyrics
# 0       [oh, babi, know, gon, na, cut, right, chase, w...
# 1       [playin, everyth, easi, like, seem, sure, stil...
# 2       [search, tender, nt, hard, find, love, need, l...
# 3       [oh, oh, oh, oh, oh, oh, wrote, book, stand, t...
# 4       [parti, peopl, peopl, parti, pop, sit, around,...
# ...                                                   ...
# 218205  [got, ta, say, boy, coupl, date, hand, outrigh...
# 218206  [help, find, diamond, ring, made, tri, everyth...
# 218207  [look, coupl, corner, booth, look, lot, like, ...
# ...

# %%
genre_year_df=english_lyrics_df[['year', 'genre']].copy()

# %%
print(genre_year_df)
# Out:
#         year    genre
# 0       2009      Pop
# 1       2009      Pop
# 2       2009      Pop
# 3       2009      Pop
# 4       2009      Pop
# ...      ...      ...
# 218205  2012  Country
# 218206  2012  Country
# 218207  2012  Country
# 218208  2012  Country
# 218209  2012  Country
#
# [218210 rows x 2 columns]

# %%
grp_genre_year = genre_year_df.groupby('genre')

# %%
grp_genre_year.tail()
# Out:
#         year       genre
# 215817  2016       Indie
# 215818  2016       Indie
# 215837  2013       Indie
# 215838  2012       Indie
# 215839  2015       Indie
# 216469  2016  Electronic
# 217197  2016         R&B
# 217198  2016         R&B
# 217202  2009        Folk
# 217203  2009        Folk
# 217204  2009        Folk
# 217205  2009        Folk
# 217206  2009        Folk
# 217324  2016         R&B
# 217325  2016         R&B
# 217326  2016         R&B
# 217881  2014        Jazz
# 217882  2014        Jazz
# 217883  2014        Jazz
# 217884  2014        Jazz
# 217885  2014        Jazz
# 218000  2007       Metal
# 218001  2007       Metal
# 218002  2007       Metal
# 218003  2007       Metal
# 218004  2007       Metal
# 218030  2016  Electronic
# 218031  2016  Electronic
# 218032  2016  Electronic
# 218033  2016  Electronic
# 218154  2016       Other
# 218155  2016       Other
# 218156  2016       Other
# 218158  2013     Hip-Hop
# 218159  2013     Hip-Hop
# 218160  2016     Hip-Hop
# ...

# %%
grp_genre_year.get_group('Indie').count()
# Out:
# year     2935
# genre    2935
# dtype: int64

# %%
count_df = pd.DataFrame({'genre': english_lyrics['genre'], 'lyrics': english_lyrics['lyrics'].str.len()})
count_df = count_df.groupby('genre')
count_df = count_df.mean()
print(word_count_df)

count_df.plot(kind='bar', y='lyrics')
# Out:
#                 lyrics
# genre
# Country      94.441305
# Electronic  106.757995
# Folk        103.551214
# Hip-Hop     275.618037
# Indie        97.747530
# Jazz         89.497401
# Metal        93.693258
# Other       116.039356
# Pop         126.100038
# R&B         114.798861
# Rock         99.204102
# <AxesSubplot:xlabel='genre'>

# %%
word_genre_df = english_lyrics.groupby('genre')
word_genre_agg_df = word_genre_df.agg({'lyrics': lambda x: list(x)})
for i in range(word_genre_agg_df['lyrics'].shape[0]):
    word_genre_agg_df['lyrics'][i] = word_genre_agg_df['lyrics'][i][0]
word_genre_agg_df
# Out:
#                                                        lyrics
# genre
# Country     [vers, 1, last, breath, life, gone, bodi, lip,...
# Electronic  [revers, behold, finit, set, thirteen, convex,...
# Folk        [rise, fall, like, tide, hand, goe, chest, ste...
# Hip-Hop     [horn, choru, timbo, hit, phone, betta, know, ...
# Indie       [nt, feel, bad, way, wheel, turn, stay, quiet,...
# Jazz        [way, leav, today, leav, hurri, find, place, c...
# Metal       [god, mountain, sky, forest, sea, land, fire, ...
# Other       [littl, thin, band, finger, left, hand, wear, ...
# Pop         [oh, babi, know, gon, na, cut, right, chase, w...
# R&B         [littl, wallflow, shelf, stand, never, nerv, t...
# Rock        [lot, cat, hatin, slander, makin, bad, stateme...

# %%
from wordcloud import WordCloud

for i in range(word_genre_agg_df.shape[0]):
    merged_string = (" ").join(word_genre_agg_df['lyrics'][i])
    word_cloud = WordCloud(height = 100, width = 200, background_color='white', max_words=10).generate(merged_string)
    plt.figure(figsize=(8,3))
    plt.imshow(word_cloud, interpolation='bilinear')
    plt.title(word_genre_agg_df.index[i])
    plt.axis('off')
    plt.show()
    plt.close()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
all_lyrics=[]
for i in range(len(english_lyrics)):
    song_lyrics_merged = (" ").join(english_lyrics['lyrics'][i])
    all_lyrics.append(song_lyrics_merged)
all_lyrics[:4]
# Out:
# ['oh babi know gon na cut right chase women made like think creat special purpos know special feel babi let get lost nt need call work caus boss real want show feel consid lucki big deal well got key heart ai nt gon na need rather open bodi show secret nt know insid need lie big wide strong wo nt fit much tough talk like caus back got big ego huge ego love big ego much walk like caus back usual humbl right nt choos leav could blue call arrog call confid decid find work damn know kill leg better yet thigh matter fact smile mayb eye boy site see kind someth like big wide strong wo nt fit much tough talk like caus back got big ego huge ego love big ego much walk like caus back walk like caus back talk like caus back back back walk like caus back big wide strong wo nt fit much tough talk like caus back got big ego huge ego huge ego love big ego much walk like caus back ego big must admit got everi reason feel like bitch ego strong ai nt know nt need beat sing piano',
# ...

# %%
#all_lyrics is corpus
vectorizer=TfidfVectorizer()
tfidfValue=vectorizer.fit_transform(all_lyrics)
tfidf_df = pd.DataFrame(tfidfValue[0].T.todense(), index=vectorizer.get_feature_names(), columns=["TF-IDF"])
tfidf_df = tfidf_df.sort_values('TF-IDF', ascending=False)
tfidf_df
# Out:
#                       TF-IDF
# ego                 0.652454
# big                 0.335330
# huge                0.255501
# back                0.217286
# caus                0.196385
# ...                      ...
# friction            0.000000
# fricta              0.000000
# frickley            0.000000
# frickiti            0.000000
# zzzzzzzzzzzzzzzzzz  0.000000
#
# [137853 rows x 1 columns]

# %%
#multinomial naive bayes
english_lyrics['complete_lyrics']=all_lyrics
english_lyrics
# Out:
#          index  year    genre  \
# 0            0  2009      Pop
# 1            1  2009      Pop
# 2            2  2009      Pop
# 3            3  2009      Pop
# 4            4  2009      Pop
# ...        ...   ...      ...
# 218205  362232  2012  Country
# 218206  362233  2012  Country
# 218207  362234  2012  Country
# 218208  362235  2012  Country
# 218209  362236  2012  Country
#
#                                                    lyrics  \
# 0       [oh, babi, know, gon, na, cut, right, chase, w...
# 1       [playin, everyth, easi, like, seem, sure, stil...
# 2       [search, tender, nt, hard, find, love, need, l...
# 3       [oh, oh, oh, oh, oh, oh, wrote, book, stand, t...
# 4       [parti, peopl, peopl, parti, pop, sit, around,...
# ...                                                   ...
# 218205  [got, ta, say, boy, coupl, date, hand, outrigh...
# 218206  [help, find, diamond, ring, made, tri, everyth...
# 218207  [look, coupl, corner, booth, look, lot, like, ...
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
X_train,X_test,y_train,y_test=train_test_split(english_lyrics['complete_lyrics'],english_lyrics['genre'], test_size=0.2)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
y_pred=pd.DataFrame(clf.predict(count_vect.transform(X_test)), columns=['genre'])
y_pred
# Out:
#       genre
# 0      Rock
# 1      Rock
# 2      Rock
# 3      Rock
# 4      Rock
# ...     ...
# 43637  Rock
# 43638  Rock
# 43639  Rock
# 43640  Rock
# 43641  Rock
#
# [43642 rows x 1 columns]

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred, target_names=english_lyrics['genre'].unique()))
# Out:
# /Users/mahekvora/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mahekvora/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          Pop       0.50      0.00      0.00      2743
#      Hip-Hop       0.00      0.00      0.00      1414
#         Rock       0.00      0.00      0.00       324
#        Metal       0.81      0.53      0.64      4530
# ...

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(english_lyrics['complete_lyrics'])
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

model = MultinomialNB().fit(X_train_tfidf, english_lyrics['genre'])

# %%
#predict lyrics
#train whole
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(english_lyrics['complete_lyrics'])
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

model = MultinomialNB().fit(X_train_tfidf, english_lyrics['genre'])

# %%
lyrics = pd.read_csv('../Desktop/song_lyrics_classifier/predict.csv')
lyrics
# Out:
#                                               lyrics
# 0  "I found a love for me Oh darling, just dive r...
# 1  "Had to have high, high hopes for a living Sho...
# 2  "Heart beats fast Colors and promises How to b...
# 3  "Trap, TrapMoneyBenny This shit got me in my f...
# 4  "Tastes like strawberries On a summer evenin' ...
# 5  "You're insecure, don't know what for You're t...

# %%
lyrics['lyrics'] = lyrics.apply(lambda row: nltk.word_tokenize(row['lyrics']), axis=1)
lyrics['lyrics'] = lyrics['lyrics'].apply(lambda x: [item.lower() for item in x])
lyrics['lyrics'] = lyrics['lyrics'].apply(lambda x: [re.sub('\W+', '', item)for item in x])

# %%
lyrics['lyrics'] = lyrics['lyrics'].apply(lambda x: [item for item in x if item not in stopWords])
lyrics['lyrics'] = lyrics['lyrics'].apply(lambda x: [port.stem(item) for item in x])

predict_lyrics = []

for i in range(len(lyrics)):
    merged_song_lyrics = (" ").join(lyrics['lyrics'][i])
    predict_lyrics.append(merged_song_lyrics)
    
lyrics['lyrics'] = predict_lyrics
lyrics
# Out:
#                                               lyrics
# 0   found love oh darl  dive right follow lead we...
# 1   high  high hope live shoot star could nt make...
# 2   heart beat fast color promis brave  love afra...
# 3   trap  trapmoneybenni shit got feel got ta rea...
# 4   tast like strawberri summer evenin  sound lik...
# 5   insecur  nt know turn head walk dooor nt need...

# %%
genre_predict = pd.DataFrame(model.predict(count_vect.transform(lyrics['lyrics'])), columns=['genre'])
genre_predict
lyrics['genre'] = genre_predict
lyrics
# Out:
#                                               lyrics    genre
# 0   found love oh darl  dive right follow lead we...     Rock
# 1   high  high hope live shoot star could nt make...     Rock
# 2   heart beat fast color promis brave  love afra...     Rock
# 3   trap  trapmoneybenni shit got feel got ta rea...  Hip-Hop
# 4   tast like strawberri summer evenin  sound lik...     Rock
# 5   insecur  nt know turn head walk dooor nt need...     Rock
